# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('mumbai_flats_cleaned_v2.csv')
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df['flat_price'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
a = df[df['flat_price'] > 30].index
df.drop(index=a,inplace=True)

# %%
df['flat_price'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['buildupArea_sqft'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
a = df[df['buildupArea_sqft'] > 5000].index
df.drop(index=a,inplace=True)

# %%
df['buildupArea_sqft'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['avg_price_thousands'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
a = df[df['avg_price_thousands']>80000].index
df.drop(index=a,inplace=True)

# %%
df['bedrooms'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[df['bedrooms'] >=7]
# Out:
#       flat_type  flat_price location1  buildupArea_sqft  avg_price_thousands  \
# 502  7 BHK Flat        21.0     Worli              3000              70000.0
#
#     age_of_property new_age         which_floor       furnishing  bedrooms  \
# 502      2 Year Old       2  Higherof 77 floors  Fully Furnished         7
#
#      bathrooms  balcony parking
# 502          5      0.0     yes

# %%
df.drop(index=502,inplace=True)

# %%
df['bathrooms'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
a = df[df['bathrooms'] >=7].index
df.drop(index=a,inplace=True)

# %%
a = df[df['balcony'] >= 6].index
df.drop(index=a,inplace=True)

# %%
df['flat_price'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['flat_price'].describe()
# Out:
# count    9509.000000
# mean        2.827899
# std         3.034652
# min         0.080000
# 25%         1.000000
# 50%         1.850000
# 75%         3.400000
# max        30.000000
# Name: flat_price, dtype: float64

# %%
q1 = df['flat_price'].quantile(0.25)
q3 = df['flat_price'].quantile(0.75)
IQR = q3-q1
lower_bound = q1- (1.5*IQR)
upper_bound = q3+ (1.5*IQR)

# %%
upper_bound
# Out:
# 7.0

# %%
df.head(5)
# Out:
#     flat_type  flat_price        location1  buildupArea_sqft  \
# 0  3 BHK Flat        3.95  Kanjurmarg West              1550
# 1  1 BHK Flat        0.19          Palghar               630
# 2  1 BHK Flat        0.73   Mira Road East               580
# 3  1 BHK Flat        1.10     Dahisar East               410
# 4  3 BHK Flat        2.25           others              1052
#
#    avg_price_thousands age_of_property new_age         which_floor  \
# 0              25480.0      3 Year Old       3  Higherof 50 floors
# 1               3020.0      3 Year Old       3   Middleof 4 floors
# 2              12590.0     1 Years Old       1   Lowerof 25 floors
# 3              26830.0     1 Years Old       1  Higherof 35 floors
# 4              21390.0     1 Years Old       1   Lowerof 26 floors
#
#         furnishing  bedrooms  bathrooms  balcony parking
# 0  Fully Furnished         3          2      1.0     yes
# 1      Unfurnished         1          1      2.0     yes
# ...

# %%
q1 = df['buildupArea_sqft'].quantile(0.25)
q3 = df['buildupArea_sqft'].quantile(0.75)
IQR = q3-q1
lower_bound = q1- (1.5*IQR)
upper_bound = q3+ (1.5*IQR)

# %%
lower_bound,upper_bound
# Out:
# (-325.0, 2275.0)

# %%
df['buildupArea_sqft'].describe()
# Out:
# count    9509.000000
# mean     1072.162688
# std       597.510124
# min       240.000000
# 25%       650.000000
# 50%       910.000000
# 75%      1300.000000
# max      4925.000000
# Name: buildupArea_sqft, dtype: float64

# %%
df['buildupArea_sqft'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.to_csv('mumbai_flats_cleaned_v3.csv',index=False)
