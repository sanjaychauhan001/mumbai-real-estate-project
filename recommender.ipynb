# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("data\\mumbai_flats_cleaned_v4.csv")

# %%
data.columns
# Out:
# Index(['flat_type', 'flat_price', 'location1', 'buildupArea_sqft',
#        'avg_price_thousands', 'age_of_propert', 'floor_type', 'furnishing',
#        'bedrooms', 'bathrooms', 'balcony', 'parking'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# flat_type               0
# flat_price              0
# location1               0
# buildupArea_sqft        0
# avg_price_thousands     0
# age_of_propert          0
# floor_type             35
# furnishing              0
# bedrooms                0
# bathrooms               0
# balcony                 0
# parking                 0
# dtype: int64

# %%
data.drop(columns=['floor_type'],inplace=True)

# %%
data.duplicated().sum()
# Out:
# 912

# %%
data.drop_duplicates(inplace=True)

# %%
data[data['flat_price']<=0.80]
# Out:
#        flat_type  flat_price       location1  buildupArea_sqft  \
# 1     1 BHK Flat        0.19         Palghar               630
# 2     1 BHK Flat        0.73  Mira Road East               580
# 17    1 BHK Flat        0.66  Mira Road East               550
# 21    1 BHK Flat        0.38      Virar West               650
# 23    1 BHK Flat        0.72  Mira Road East               740
# ...          ...         ...             ...               ...
# 8363  1 BHK Flat        0.60  Bhayandar West               510
# 8368  1 BHK Flat        0.36      Virar West               680
# 8372  1 BHK Flat        0.68    Bhandup West               350
# 8383  2 BHK Flat        0.65  Mira Road East               625
# 8384  1 BHK Flat        0.20    Naigaon East               280
#
#       avg_price_thousands       age_of_propert      furnishing  bedrooms  \
# 1                  3020.0  recent construction     Unfurnished         1
# 2                 12590.0     new construction  Semi Furnished         1
# 17                12000.0     new construction  Semi Furnished         1
# 21                 5850.0  recent construction  Semi Furnished         1
# 23                 9730.0  recent construction  Semi Furnished         1
# ...                   ...                  ...             ...       ...
# 8363              11760.0     mid age property  Semi Furnished         1
# 8368               5290.0     new construction     Unfurnished         1
# 8372              19430.0      modern property     Unfurnished         1
# 8383              10400.0      modern property  Semi Furnished         2
# 8384               7140.0  recent construction  Semi Furnished         1
#
#       bathrooms  balcony parking
# 1             1        2     yes
# 2             2        2      no
# 17            1        1     yes
# 21            1        2     yes
# 23            2        3     yes
# ...         ...      ...     ...
# 8363          1        0     yes
# 8368          1        1     yes
# 8372          1        0      no
# 8383          2        0      no
# 8384          1        0      no
#
# [1201 rows x 11 columns]

# %%
def recommend_flats(data, location=None, bhk_type=None, min_price=None, max_price=None, min_area=None, max_area=None, top_n=5):
    
    filtered_data = data.copy()
    if location:
        filtered_data = filtered_data[filtered_data['location1'] == location]
    if bhk_type:    
        filtered_data = filtered_data[filtered_data['flat_type'] == bhk_type]

    if min_price is not None:
        filtered_data = filtered_data[filtered_data['flat_price'] >= min_price]
    if max_price is not None:
        filtered_data = filtered_data[filtered_data['flat_price'] <= max_price]

    if min_area is not None:
        filtered_data = filtered_data[filtered_data['buildupArea_sqft'] >= min_area]
    if max_area is not None:
        filtered_data = filtered_data[filtered_data['buildupArea_sqft'] <= max_area]

    recommended_flats = filtered_data.sort_values(by='flat_price').head(top_n)
    return recommended_flats

# %%
recommend_flats(data=data,bhk_type="2 BHK Flat",min_price=0.80,max_price=2.0,min_area=500,max_area=1200,top_n=5)
# Out:
#        flat_type  flat_price       location1  buildupArea_sqft  \
# 1886  2 BHK Flat         0.8  Mira Road East              1050
# 5911  2 BHK Flat         0.8    Dahisar East               882
# 5721  2 BHK Flat         0.8      Vasai West               930
# 5035  2 BHK Flat         0.8  Bhayandar East              1050
# 5315  2 BHK Flat         0.8   Goregaon East               972
#
#       avg_price_thousands       age_of_propert       furnishing  bedrooms  \
# 1886               7610.0  recent construction   Semi Furnished         2
# 5911               9070.0     new construction      Unfurnished         2
# 5721               8600.0  recent construction   Semi Furnished         2
# 5035               7610.0  recent construction   Semi Furnished         2
# 5315               8230.0  recent construction  Fully Furnished         2
#
#       bathrooms  balcony parking
# 1886          2        3     yes
# 5911          2        3     yes
# 5721          2        0     yes
# 5035          2        3     yes
# 5315          2        0     yes

# %%
data['flat_type'].
# Out:
#        flat_type  flat_price        location1  buildupArea_sqft  \
# 0     3 BHK Flat        3.95  Kanjurmarg West              1550
# 1     1 BHK Flat        0.19          Palghar               630
# 2     1 BHK Flat        0.73   Mira Road East               580
# 3     1 BHK Flat        1.10     Dahisar East               410
# 4     3 BHK Flat        2.25           others              1052
# ...          ...         ...              ...               ...
# 8380  2 BHK Flat        2.25          Chembur               960
# 8381  3 BHK Flat        2.85          Chembur               865
# 8382  3 BHK Flat        2.60      Mulund West               886
# 8383  2 BHK Flat        0.65   Mira Road East               625
# 8384  1 BHK Flat        0.20     Naigaon East               280
#
#       avg_price_thousands       age_of_propert       furnishing  bedrooms  \
# 0                 25480.0  recent construction  Fully Furnished         3
# 1                  3020.0  recent construction      Unfurnished         1
# 2                 12590.0     new construction   Semi Furnished         1
# 3                 26830.0     new construction   Semi Furnished         1
# 4                 21390.0     new construction   Semi Furnished         3
# ...                   ...                  ...              ...       ...
# 8380              23440.0  recent construction   Semi Furnished         2
# 8381              32950.0  recent construction   Semi Furnished         3
# 8382              29340.0      modern property  Fully Furnished         3
# 8383              10400.0      modern property   Semi Furnished         2
# 8384               7140.0  recent construction   Semi Furnished         1
#
#       bathrooms  balcony parking
# 0             2        1     yes
# 1             1        2     yes
# 2             2        2      no
# 3             2        1     yes
# 4             2        3     yes
# ...         ...      ...     ...
# 8380          2        0     yes
# 8381          3        0     yes
# 8382          3        0     yes
# 8383          2        0      no
# 8384          1        0      no
#
# [7473 rows x 11 columns]

# %%
data
# Out:
#        flat_type  flat_price        location1  buildupArea_sqft  \
# 0     2 BHK Flat        0.95   Mira Road East              1060
# 1     1 BHK Flat        0.93    Borivali East               525
# 2     2 BHK Flat        1.48     Bhandup West              1065
# 3     3 BHK Flat        2.50     Bhandup West              1150
# 4     1 BHK Flat        1.10      Wadala East               480
# ...          ...         ...              ...               ...
# 7478  1 BHK Flat        0.74       Malad West               550
# 7479  1 BHK Flat        0.24  Nalasopara West               700
# 7480  1 BHK Flat        0.99       Malad West               650
# 7481  2 BHK Flat        1.28     Bhandup West               950
# 7482  1 BHK Flat        0.48   Mira Road East               540
#
#           age_of_property      furnishing  bedrooms  bathrooms  balcony  \
# 0     recent construction  Semi Furnished         2          2        0
# 1        mid age property  Semi Furnished         1          2        0
# 2        new construction  Semi Furnished         2          2        1
# 3     recent construction  Semi Furnished         3          2        0
# 4        new construction     Unfurnished         1          2        0
# ...                   ...             ...       ...        ...      ...
# 7478      modern property     Unfurnished         1          1        0
# 7479  recent construction     Unfurnished         1          1        0
# 7480     new construction     Unfurnished         1          2        0
# 7481  recent construction     Unfurnished         2          2        2
# 7482  recent construction     Unfurnished         1          2        0
#
#      parking
# 0        yes
# 1         no
# 2        yes
# 3        yes
# 4        yes
# ...      ...
# 7478      no
# 7479     yes
# 7480     yes
# 7481     yes
# 7482     yes
#
# [7483 rows x 10 columns]
