# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('mumbai_flats_cleaned_v4.csv')
df
# Out:
#        flat_type  flat_price        location1  buildupArea_sqft  \
# 0     3 BHK Flat        3.95  Kanjurmarg West              1550
# 1     1 BHK Flat        0.19          Palghar               630
# 2     1 BHK Flat        0.73   Mira Road East               580
# 3     1 BHK Flat        1.10     Dahisar East               410
# 4     3 BHK Flat        2.25           others              1052
# ...          ...         ...              ...               ...
# 8380  2 BHK Flat        2.25          Chembur               960
# 8381  3 BHK Flat        2.85          Chembur               865
# 8382  3 BHK Flat        2.60      Mulund West               886
# 8383  2 BHK Flat        0.65   Mira Road East               625
# 8384  1 BHK Flat        0.20     Naigaon East               280
#
#       avg_price_thousands       age_of_propert floor_type       furnishing  \
# 0                 25480.0  recent construction     Higher  Fully Furnished
# ...

# %%
df['flat_type'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='flat_type'>

# %%
df['flat_price'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
np.log1p(df['flat_price']).plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['location1'].value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='location1'>

# %%
df['buildupArea_sqft'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['avg_price_thousands'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['age_of_propert'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='age_of_propert'>

# %%
df['floor_type'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='floor_type'>

# %%
df['furnishing'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='furnishing'>

# %%
df['bedrooms'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['bathrooms'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='bathrooms'>

# %%
df['balcony'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='balcony'>

# %%
a = df[(df['balcony'] == 5) & (df['bedrooms'] <=3)].index
df.drop(index=a,inplace=True)

# %%
df['parking'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='parking'>

# %%
df.to_csv('mumbai_flats_cleaned_v5.csv',index=False)
